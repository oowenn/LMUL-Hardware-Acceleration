# %%
from lmul_nn_funcs import lmul_bits

def lmul(a, b):
    return lmul_bits(a, b)

print("LMUL loaded")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from lmul_nn_funcs import lmul_bits
#       3 def lmul(a, b):
#       4     return lmul_bits(a, b)
#
# ModuleNotFoundError: No module named 'lmul_nn_funcs'
