# %%
from IPython.display import HTML, display

html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>L-Mul</title>
    <link rel="preconnect" href="https://fonts.googleapis.com">
    <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
    <link href="https://fonts.googleapis.com/css2?family=IBM+Plex+Mono:wght@400;500;600&family=Sora:wght@300;400;500;600;700&display=swap" rel="stylesheet">
    <style>
        :root {
            --bg: #fafafa;
            --bg-alt: #f0f0f0;
            --text: #1a1a1a;
            --text-light: #666;
            --text-muted: #999;
            --accent: #2563eb;
            --border: #e0e0e0;
            --font-body: 'Sora', sans-serif;
            --font-mono: 'IBM Plex Mono', monospace;
        }

        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        body {
            font-family: var(--font-body);
            background: var(--bg);
            color: var(--text);
            line-height: 1.6;
            font-size: 16px;
        }

        a {
            color: var(--accent);
            text-decoration: none;
        }

        a:hover {
            text-decoration: underline;
        }

        /* Nav */
        nav {
            padding: 1.5rem 2rem;
            display: flex;
            justify-content: space-between;
            align-items: center;
            max-width: 1000px;
            margin: 0 auto;
        }

        .logo {
            font-family: var(--font-mono);
            font-weight: 600;
            font-size: 1.1rem;
            color: var(--text);
        }

        .nav-link {
            font-size: 0.9rem;
            color: var(--text-light);
        }

        /* Main */
        main {
            max-width: 700px;
            margin: 0 auto;
            padding: 2rem 2rem 6rem;
        }

        /* Hero */
        .hero {
            margin-bottom: 4rem;
        }

        .hero h1 {
            font-size: 2rem;
            font-weight: 600;
            margin-bottom: 1rem;
            line-height: 1.3;
        }

        .hero p {
            color: var(--text-light);
            font-size: 1.05rem;
            margin-bottom: 1.5rem;
        }

        .hero-meta {
            font-size: 0.85rem;
            color: var(--text-muted);
        }

        /* Sections */
        section {
            margin-bottom: 4rem;
        }

        section h2 {
            font-size: 1.1rem;
            font-weight: 600;
            margin-bottom: 1.5rem;
            padding-bottom: 0.5rem;
            border-bottom: 1px solid var(--border);
        }

        /* Placeholder */
        .placeholder {
            background: var(--bg-alt);
            border: 1px dashed var(--border);
            border-radius: 8px;
            padding: 2rem;
            text-align: center;
            color: var(--text-muted);
            font-size: 0.9rem;
        }

        /* Team */
        .team-list {
            list-style: none;
        }

        .team-list li {
            padding: 0.75rem 0;
            border-bottom: 1px solid var(--border);
            display: flex;
            justify-content: space-between;
            align-items: center;
        }

        .team-list li:last-child {
            border-bottom: none;
        }

        .team-name {
            font-weight: 500;
        }

        .team-role {
            font-family: var(--font-mono);
            font-size: 0.8rem;
            color: var(--text-muted);
        }

        .advisor {
            margin-top: 1.5rem;
            padding-top: 1rem;
            border-top: 1px solid var(--border);
            font-size: 0.9rem;
            color: var(--text-light);
        }

        /* Footer */
        footer {
            max-width: 700px;
            margin: 0 auto;
            padding: 2rem;
            border-top: 1px solid var(--border);
            font-size: 0.85rem;
            color: var(--text-muted);
            display: flex;
            justify-content: space-between;
        }

        /* Responsive */
        @media (max-width: 600px) {
            nav, main, footer {
                padding-left: 1.25rem;
                padding-right: 1.25rem;
            }

            .hero h1 {
                font-size: 1.6rem;
            }

            .team-list li {
                flex-direction: column;
                align-items: flex-start;
                gap: 0.25rem;
            }
        }
    </style>
</head>
<body>
    <nav>
        <span class="logo">L-Mul</span>
        <a href="https://github.com/oowenn/LMUL-Hardware-Acceleration" class="nav-link">github ↗</a>
    </nav>

    <main>
        <section class="hero">
            <h1>Hardware acceleration for neural network inference</h1>
            <p>
                We're exploring L-Mul, an algorithm that approximates floating-point 
                multiplication using addition. The idea is to make neural network 
                inference faster and more energy-efficient on custom hardware.
            </p>
            <p class="hero-meta">DSC 180 Capstone · UC San Diego · Winter 2026</p>
        </section>

        <section id="about">
            <h2>What is this?</h2>
            <div class="placeholder">
                coming soon — will explain the project motivation and goals
            </div>
        </section>

        <section id="how">
            <h2>How it works</h2>
            <div class="placeholder">
                coming soon — will explain the L-Mul algorithm
            </div>
        </section>

        <section id="results">
            <h2>Results</h2>
            <div class="placeholder">
                coming soon — will show accuracy and hardware metrics
            </div>
        </section>

        <section id="team">
            <h2>Team</h2>
            <ul class="team-list">
                <li>
                    <span class="team-name">Owen Shi</span>
                    <span class="team-role">hardware / gem5</span>
                </li>
                <li>
                    <span class="team-name">Edgar Guzman</span>
                    <span class="team-role">verilog / vivado</span>
                </li>
                <li>
                    <span class="team-name">Idhant Kumar</span>
                    <span class="team-role">synthesis / power</span>
                </li>
                <li>
                    <span class="team-name">Brendan Kuang</span>
                    <span class="team-role">llm / transformers</span>
                </li>
                <li>
                    <span class="team-name">Brandon Chiou</span>
                    <span class="team-role">eyeriss / testbench</span>
                </li>
                <li>
                    <span class="team-name">Pranav Kumarsubha</span>
                    <span class="team-role">ablation / website</span>
                </li>
            </ul>
            <p class="advisor">Advised by Professor Rajesh Gupta</p>
        </section>
    </main>

    <footer>
        <span>HDSI @ UCSD</span>
        <span>2026</span>
    </footer>
</body>
</html>
"""

display(HTML(html_code))
# Out:
# <your html here>
